# %%
import pandas as pd
import numpy as np

# %%
course_data = pd.read_csv("course.csv",sep = ";",header = None)
students = pd.read_csv("students.csv",sep = ";",header = None,encoding = "ISO-8859-1")

# %%
course_data[0]
courses = []
arr = []
for i in range(len(course_data[0])):
    arr.append(course_data[0][i])
    if (i+1) % 31 == 0:
        courses.append(arr)
        arr = []
courses
#students[4]
# Out:
# [['MATH101',
#   'ACWR101',
#   'CHEM101',
#   'PHYS101',
#   'CHBI101',
#   'SOSC101',
#   'ENGR101',
#   'COMP101',
#   'ASIU101',
#   'HUMS101',
#   'ETHC101',
#   'MBGE101',
#   'ELEC101',
#   'INDR101',
#   'MECH101',
#   'ECON101',
#   'ACCT101',
#   'MKTG101',
#   'MFIN101',
#   'QMBU101',
#   'SCIE101',
#   'INTL101',
#   'HIST101',
#   'ARHA101',
#   'LITR101',
#   'MAVA101',
#   'PSYC101',
#   'EQUR101',
#   'SOCI101',
#   'PHIL101',
#   'LAW101'],
#  ['MATH102',
#   'ACWR102',
#   'CHEM102',
#   'PHYS102',
#   'CHBI102',
#   'SOSC102',
#   'ENGR102',
#   'COMP102',
#   'ASIU102',
#   'HUMS102',
#   'ETHC102',
#   'MBGE102',
#   'ELEC102',
#   'INDR102',
#   'MECH102',
#   'ECON102',
#   'ACCT102',
#   'MKTG102',
#   'MFIN102',
#   'QMBU102',
#   'SCIE102',
#   'INTL102',
#   'HIST102',
#   'ARHA102',
#   'LITR102',
#   'MAVA102',
#   'PSYC102',
#   'EQUR102',
#   'SOCI102',
#   'PHIL102',
#   'LAW102'],
#  ['MATH201',
#   'ACWR201',
#   'CHEM201',
#   'PHYS201',
# ...

# %%
import random
arr = []
enrolled = []
grades = ["F","D","D+","C-","C","C+","B-","B","B+","A-","A"]
for i in range(len(students[0])):
    class_ = students[4][i]
    for t in range (class_*2):
        arr = random.sample(courses[t], 5)
        for k in range(5):
            temp = random.sample(grades, 1)
            if t == (class_*2 -1):
                enn_arr = [students[2][i],arr[k],"Null"]
            else:
                enn_arr = [students[2][i],arr[k],temp[0]]
            enrolled.append(enn_arr)
#df = pd.DataFrame(enrolled)
#df.to_csv('enrolled.csv')

# %%
arr = []
online = []
ftof = []
classroom = range(1000, 1200)
for i in range (len(course_data)):
    if i%2 == 0:
        num2 = random.randint(50, 120)
        temp = random.sample(classroom, 1)
        ftof.append([course_data[0][i],num2,temp[0]])
    else:
        online.append([course_data[0][i],"meet.google.com/"+course_data[0][i]])

# %%
students = pd.read_csv("students.csv",sep = ";",header = None,encoding = "ISO-8859-1")

# %%
students[8]
arr0 = ["Chemistry","Physics","Mathematics","Molecular Biology and Genetics"]
arr1 = ["Business Administration","Economy","International Relations"]
arr2 = ["Chemical and Biological Engineering ","Computer Engineering","Electrical and Electronics Engineering","Industrial Engineering","Mechanical Engineering"]
arr3 = ["Law"]
arr4 = ["History","Archaeology and History of Art","Comparative Literature","Media and Visual Arts","Psychology","Sociology","Philosophy"]
arr = [arr0,arr1,arr2,arr3,arr4]
temp = []
for i in range(len(students[0])):
    faculty = students[8][i]
    temp__ = random.sample(arr[faculty], 1)
    temp.append(temp__[0])

# %%
temp
#df = pd.DataFrame(temp)
#df.to_csv('temp.csv')

# %%
students = pd.read_csv("instructor.csv",sep = ";",header = None ,encoding = "ISO-8859-1",dtype = {0: int , 1 : str,2:str,3:str})

# %%
df = pd.DataFrame(students)
df.to_csv('instructors.csv',index = False)

# %%
type(df[1][1])
# Out:
# str
